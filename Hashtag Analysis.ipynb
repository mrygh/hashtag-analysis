# %%
pip install -U selenium
# Out:
# Requirement already up-to-date: selenium in /opt/anaconda3/lib/python3.7/site-packages (3.141.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import datetime

# %%
#taglist=['jewelry', 'bodyjewelry', 'bodyjewellery', 'piercing',  'piercingsofinstagram','piercingjewelry', 'bodypiercing', 'bellypiercing', 'bellybuttonpiercing']
#taglist=["elevatedaesthetics"] , "papermacheart", "iraniandesigner" ,"persiandedigner" ,"recycledjewelry", "papiemachejewelry", "paperjewelry"
#taglist=["persianjewelry", "arabicjewelry", "initialstuds"]
#taglist = ['afrartgallery','persianjewelry','persianpatterns', 'persianstyle', 'persiangift', 'onlineshopping','persian_art','shoplocal', 'handmadejewelry','to_persiangiftshop', 'iranart','shopsmall','iranianhandicrafts', 'iranianart', 'persiandesigner', 'sharingbeautyforempowerment']
#taglist =['popart','madeinusa','iraniandesigner','iranianartist']
#taglist=['afrartgallery', 'brassring', 'agatejewelry', 'ringlover', 'instaring', 'persianjewelry']
#taglist=['persianbeauty', 'handmadejewelry','onlineshopping', 'persianonlineshop', 'persianhandmadeaccessories', 'to_persiangiftshop', 'sharingbeautyforempowerment']
#taglist=['torontojewelry', 'earrings', 'onlineshop', 'sterlingsilver', 'unique','pearl', 'artistic', 'leafearrings', 'unique']

#taglist=['springiscomming', 'enameljewelry', 'handengraving', 'brassearrings' ,'ethnicearrings', 'geometricjewelry',
# 'colorfulearrings', 'dropearrings' ,'dangleearrings', 'hypoallergenic' ,'persianbeauty' ,'torontopersian', 'localbusiness', 'onlinestore',
#  'middleeasternart', 'geometricpattern', 'giftforher', 'unique', 'persiangiftshop', 'persianart', 'buyonline',
#   'readytoship' ,'beunique' ,'middleeasternart', 'coinjewelry', 'silverearrings', 'golden', '18kgold', 'middleeastart', 'middleeastfashion', 'authentic',
# 'authenticjewelry', 'vintagestyle',  'toronto', 'persiangiftshop', 'middleeastern', 'persianbeauty', 'iraniandesign','to_persiangiftshop', 'localbusiness', 'supportwomenartists',  
#'baluchistan', 'iran', 'handenbroidery', 'embroideryart', 'embroideryjewelry',  'balochistan', 'needlecraft',
# 'persian_art', 'persianbeauty', 'iraniandesigner', 'persiandesign', 'bohostyle', 'bohochic', 'toronto',
#  'the6ix', 'onlineboutique', 'persiangift',  'supportlocal','wearableart', 'artforchange', 'to_persian', 'to_persiangiftshop',
# 'studearrings', 'goldplated', 'minimalism' ,'bohochic' , 'persiangirl',  'shoplocal', 'daintyjewelry', 'subtle', 'casualjewelry',
#'instaearrings', 'steeljewelry', 'persianpattern', 'culturalexchange', 'wearableart', 'wearableicon', 'icone' ,
#'beautifulhomes', 'subtle', 'torontolife', 'blogto']
#taglist=['persianstyle','persianstyle',	'persianjewelry',	'persianstyle',	'persianstyle',	'persian',	'persianstyle',	'persianstyle',	'mirrormosaics',	'instaring',	'persiangiftshop',	'middleeasternart',	'persiangift',	'persiangift',	'persiandesigner',	'persiangift',	'persiangift',	'saveourculture',	'persiangift',	'persiangift',	'mirrorjewellery',	'fatherdaygift',	'silvercuff',	'balochistan',	'lapislazuli',	'colorfuljewelry',	'persianbeauty',	'agatejewelry',	'colorfuljewelry',	'womanempowerment',	'redgemstone',	'colorfuljewelry',	'persianhandmadeaccessories',	'ringlover',	'handengraving',	'needlecraft',	'onlineshopping',	'onlineshopping',	'persiangift',	'onlineshopping',	'onlineshopping',	'cultureexchange',	'onlineshopping',	'onlineshopping',	'to',	'persiancalligraphy',	'doublesided',	'persian_art',	'orderonline',	'persian_art',	'persiangirl',	'orderonline',	'orderonline',	'wearetogether',	'orderonline',	'orderonline',	'onlineboutique',	'persianjewelry',	'handengraved',	'persianbeauty']
#taglist=['persian_art',	'persianonlineshop',	'persiangift',	'persian_art',	'persian_art',	'sharingbeautyforempowerment',	'persian_art',	'persian_art',	'persiangiftshop',	'persianhandmadeaccessories',	'persianart',	'iraniandesigner',	'persianonlineshop',	'persiangiftshop',	'shoplocal',	'persianonlineshop',	'persianonlineshop',	'persianonlineshop',	'persianonlineshop',	'giftideas',	'to_persiangiftshop',	'torontopersian',	'persiandesign',	'persiangiftshop',	'torontogiftshop',	'daintyjewelry',	'persiangiftshop',	'persiangiftshop',	'persiangiftshop',	'persiangiftshop',	'mirrormosaic',	'persiangift',	'mehr',	'bohostyle',	'torontogiftshop',	'to_persiangiftshop',	'subtle',	'torontogiftshop',	'torontogiftshop',	'torontogiftshop',	'torontogiftshop',	'jewellery',	'onlineshopping',	'love',	'bohochic',	'to_persiangiftshop',	'iranart',	'casualjewelry',	'to_persiangiftshop',	'to_persiangiftshop',	'to_persiangiftshop',	'to_persiangiftshop',	'handmadechoker',	'persiancalligraphy',	'persiannewyear']
#taglist=['iranart',	'persianonlinestore',	'sharingbeautyforempowerment',	'iranart',	'iranart',	'iranart',	'iranart',	'chokernecklace',	'trendyjewelry',	'calligraphyart',	'the6ix',	'persianonlinestore',	'persianhandmadeaccessories',	'persianonlinestore',	'persianonlinestore',	'persianonlinestore',	'persianonlinestore',	'sharingbeautyforempowerment',	'sharingbeautyforempowerment',	'bohostyle',	'onlineboutique',	'shoplocal',	'wearableart',	'shoplocal',	'persianhandmadeaccessories',	'persianhandmadeaccessories',	'persianhandmadeaccessories',	'persianart',	'hich',	'persiangift',	'persianhandmadeaccessories',	'jewelrymaking',	'persianhandmadeaccessories',	'wearableart',	'wearableart',	'wearableart',	'iranianjewelry',	'wearableart',	'supportwomenartists',	'wearableart',	'dropearrings',	'wearableart',	'icone',	'icone',	'icone',	'iraniandesign',	'persianbeauty',	'supportlocal']
taglist=['uniquejewelry','iranian_art',"afrajewelry",'readytoship','minimalistjewelry','iranianhandicrafts','subtlejewelry',	'giftforher',	'subtlejewelry',	'dropearrings',	'dropearrings',	'dropearrings',	'persiandesigner',	'middleeastart',	'wearableart',	'shopsmall',	'torontojewellery',	'shopsmall',	'giftforher',	'giftforher',	'giftforher',	'toronto',	'uniquegifts',	'handmadejewelry',	'giftforher',	'enameljewelry',	'giftforher',	'torontojewellery',	'torontojewellery',	'torontojewellery',	'bohostyle',	'to_persiangiftshop',	'persianhandmadeaccessories',	'torontojewellery',	'torontopersian',	'torontojewellery',	'enameljewelry',	'torontopersian',	'enameljewelry',	'persiandesign',	'persianhandmadeaccessories',	'torontopersian',	'iranianhandicrafts',	'torontopersian',	'torontopersian',	'iranianhandicrafts',	'torontopersian',	'persianbeauty',	'torontohandmadejewelry',	'to_persiangiftshop',]

# %%
driver = webdriver.Chrome('/Users/maryamgholami/Downloads/chromedriver 2')

# Extract description of a post from Instagram link
#driver.get('https://www.instagram.com/p/BiRnjDsFKzl/')
#soup = BeautifulSoup(driver.page_source,"lxml")
#desc = " "

#for item in soup.findAll('a'):
#    desc= desc + " " + str(item.string)

# Extract tag list from Instagram post description
#taglist = desc.split()
#taglist = [x for x in taglist if x.startswith('#')]
#index = 0
#while index < len(taglist):
#    taglist[index] = taglist[index].strip('#')
#    index += 1

# (OR) Copy-paste your tag list manually here

#,

#taglist =['piercingjewelry', 'bodypiercing', 'bellypiercing', 'bellybuttonpiercing']
print(taglist)


# Define dataframe to store hashtag information
tag_df  = pd.DataFrame(columns = ['Hashtag', 'Number of Posts', 'Posting Freq (mins)'])

# Loop over each hashtag to extract information
for tag in taglist:
    
    driver.get('https://www.instagram.com/explore/tags/'+str(tag))
    soup = BeautifulSoup(driver.page_source,"lxml")
    
    # Extract current hashtag name
    tagname = tag
    # Extract total number of posts in this hashtag
    # NOTE: Class name may change in the website code
    # Get the latest class name by inspecting web code
    nposts = soup.find('span', {'class': 'g47SY'}).text
        
    # Extract all post links from 'explore tags' page
    # Needed to extract post frequency of recent posts
    myli = []
    for a in soup.find_all('a', href=True):
        myli.append(a['href'])

    # Keep link of only 1st and 9th most recent post 
    newmyli = [x for x in myli if x.startswith('/p/')]
    del newmyli[:9]
    del newmyli[9:]
    del newmyli[1:8]

    timediff = []

    # Extract the posting time of 1st and 9th most recent post for a tag
    for j in range(len(newmyli)):
        driver.get('https://www.instagram.com'+str(newmyli[j]))
        soup = BeautifulSoup(driver.page_source,"lxml")

        for i in soup.findAll('time'):
            if i.has_attr('datetime'):
                timediff.append(i['datetime'])
                #print(i['datetime'])

    # Calculate time difference between posts
    # For obtaining posting frequency
    datetimeFormat = '%Y-%m-%dT%H:%M:%S.%fZ'
    diff = datetime.datetime.strptime(timediff[0], datetimeFormat)\
        - datetime.datetime.strptime(timediff[1], datetimeFormat)
    pfreq= int(diff.total_seconds()/(9*60))
    #pfreq= diff.total_seconds()
    # Add hashtag info to dataframe
    tag_df.loc[len(tag_df)] = [tagname, nposts, pfreq]
        
driver.quit()

# Check the final dataframe
print(tag_df)

# CSV output for hashtag analysis
tag_df.to_csv('hashtag_list.csv')
# Out:
# ['uniquejewelry', 'iranian_art', 'afrajewelry', 'readytoship', 'minimalistjewelry', 'iranianhandicrafts', 'subtlejewelry', 'giftforher', 'subtlejewelry', 'dropearrings', 'dropearrings', 'dropearrings', 'persiandesigner', 'middleeastart', 'wearableart', 'shopsmall', 'torontojewellery', 'shopsmall', 'giftforher', 'giftforher', 'giftforher', 'toronto', 'uniquegifts', 'handmadejewelry', 'giftforher', 'enameljewelry', 'giftforher', 'torontojewellery', 'torontojewellery', 'torontojewellery', 'bohostyle', 'to_persiangiftshop', 'persianhandmadeaccessories', 'torontojewellery', 'torontopersian', 'torontojewellery', 'enameljewelry', 'torontopersian', 'enameljewelry', 'persiandesign', 'persianhandmadeaccessories', 'torontopersian', 'iranianhandicrafts', 'torontopersian', 'torontopersian', 'iranianhandicrafts', 'torontopersian', 'persianbeauty', 'torontohandmadejewelry', 'to_persiangiftshop']
#                        Hashtag Number of Posts Posting Freq (mins)
# ...

# %%
loader = Instaloader()
NUM_POSTS = 10

def get_hashtags_posts(query):
    posts = loader.get_hashtag_posts(query)
    users = {}
    count = 0
    for post in posts:
        profile = post.owner_profile
        if profile.username not in users:
            summary = engagement.get_summary(profile)
            users[profile.username] = summary
            count += 1
            print('{}: {}'.format(count, profile.username))
            if count == NUM_POSTS:
                break
    return users

# %%
import threading
from instaloader import Instaloader, Profile
import engagement1
import pickle

loader = Instaloader()
NUM_POSTS = 100000

def get_hashtags_posts(query):
    posts = loader.get_hashtag_posts(query)
    users = {}
    count = 0
    for post in posts:
        profile = post.owner_profile
        if profile.username not in users:
            summary = engagement1.get_summary(profile)
            users[profile.username] = summary
            count += 1
            print('{}: {}'.format(count, profile.username))
            if count == NUM_POSTS:
                break
    return users

if __name__ == "__main__":
    hashtag = "iran"
    users = get_hashtags_posts(hashtag)
    print(users)
# Out:
# 1: jeep_ahoo313
# 2: persia.bmw
# 3: nnono.nnono.1848
# 4: boutique_beautifull
# 5: afghanimedia
# 6: shirinkhodayar1
# 7: mehdi.khalili.rama
# 8: erfan.ahmadi.z
# 9: hojatgolizadeh_officiall
# 10: cznburak06
# 11: alborzpainterartists
# 12: nazk.kurd
# 13: shvan_poshak
# 14: itsalimoradii
# 15: natural_graphy_
# 16: sya._.work
# 17: tehweather
# 18: farnazrabieh
# 19: elcafe.tab
# 20: serenmertabiye
# 21: sepahanfc_official
# 22: mukazemi
# 23: edit_video.benaf
# 24: iran_iranians
# 25: sajjad.photo.4
# 26: karbalaemuala
# 27: asre_zohoure_mahdi
# 28: tourist_city
# 29: eris_producer
# 30: semanindunyasi2
# 31: onun.zuhuru
# 32: ebrahimalizadeh13
# 33: youcanprotestwithoutothers
# 34: sanaz._z.r
# 35: anila_.baloch
# 36: pa_r_en
# 37: nematss7
# 38: best_iraniann_models
# 39: bahai_sul
# 40: rozhinavasemi_photography
# 41: sardasht_tourism
# 42: mehdigohari.music
# 43: hajmhti_
# 44: onddbdiiij
# 45: saad0_o
# 46: faaan_kadeh
# 47: foolad_asia
# 48: l_yoohaha_l
# 49: akbarnemati
# ...
